# %%
#We get the training data from the models here to make the histograms

import matplotlib.pyplot as plt

results = {
    "resnet18": 61.34,
    "resnet34": 76.34,
    "resnet50": 51.93,
    "mobile": 61.14, 
    "densenet": 63.16,
    "googlenet": 81.58,
    "alexnet": 65.79, 
    "squeezenet": 60.53, 
    
    }


plt.figure(figsize=(10, 6))
plt.bar(results.keys(), results.values(), color='lightgreen')
plt.xlabel('Model')
plt.ylabel('Validation Accuracy (%)')
plt.title('Validation Accuracies of Various ML Models')
plt.ylim(0, 100)  
plt.xticks(rotation=45)
plt.show()
