# %% [markdown]
# # In this cell, we will perform Data Cleaning

# %%
# !unzip /content/All_Labels_4000_Three.zip -d /content/
# Out:
# Archive:  /content/All_Labels_4000_Three.zip
#    creating: /content/All_Labels_4000_Three/Algae/
#    creating: /content/All_Labels_4000_Three/Algae/CAL_CCA_DC/
#   inflating: /content/All_Labels_4000_Three/Algae/CAL_CCA_DC/42008137001780441.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/CAL_CCA_DC/42008137001788602.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/CAL_CCA_DC/42008138001840765.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/CAL_CCA_DC/4200907720122792.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/CAL_CCA_DC/42009077601409753.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/CAL_CCA_DC/42009078001216282.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/CAL_CCA_DC/4200907900110581167.jpg
#    creating: /content/All_Labels_4000_Three/Algae/EAM_DHC/
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041461011010173.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041461011091120.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041461011243323.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041461011253896.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041461011399166.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414610114801502.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414610116111778.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414610116611504.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146101399487.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041461017301695.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041462011017277.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146201108163.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414620112521391.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414620112771315.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414620116941414.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414620117461067.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414620117741752.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414620118421519.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414620118621670.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041462012701196.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146201591304.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146201609184.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146201710601.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146201797147.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146201898418.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146201946448.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146201955151.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146201961799.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414630110221070.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414630110341195.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041463011274464.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041463011313674.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146301171770.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146301209863.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146301272838.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146301312988.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146301326633.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041463014201014.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146301701018.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146301730829.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414630177771.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146301990205.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146401138156.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146401376191.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146401426372.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146401455504.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146401498551.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146401518352.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146401553354.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146401569683.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146401643293.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146501123192.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146501129240.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146501171217.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146501172273.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146501206252.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414650120754.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146501275112.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146501319138.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146501546399.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414650158208.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146601113449.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041466011161194.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041466011175455.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146601124266.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146601212709.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146601224512.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146601411533.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146601421623.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146601486452.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146601498891.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146601683969.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146601722972.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146601743544.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146601796442.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041466018281173.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146601925305.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146601981384.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041467011278581.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041467011366635.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041467011457374.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041467011606685.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041467011618713.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041467011619760.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041467011962984.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041467012841740.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146701316360.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041467013411047.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146701347794.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146701358950.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041467013851028.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041467014221178.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146701508723.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146701538544.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146701547405.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146701783349.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041468011008909.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414680111321117.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041468012181351.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146801225523.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041468012341410.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146801367279.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414690110221591.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414690110311544.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041469011084951.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041469011118997.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041469011130284.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041469011421859.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041469011434283.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004146901154599.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041469011602924.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041469011694358.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041469011698873.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041469011784196.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041469011797875.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041469013141385.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041469016301036.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470011010140.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470011152643.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470011165707.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470011321187.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470011385122.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470011396438.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470011465187.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414700115031553.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470011509363.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470011534554.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470011537329.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414700115571302.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470011574852.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470011653216.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470011683621.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470011695309.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414700117461191.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470011854458.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470013601389.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041470014941337.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147001577264.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147001804396.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147001961303.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471011010148.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471011132559.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414710111551521.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471011239789.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471011257397.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471011300973.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471011371563.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471011411468.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471011417659.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471011488232.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471011489491.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147101159384.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471011761310.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471011891554.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147101274596.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147101293309.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147101366493.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471013761362.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147101385310.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471013871013.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147101389804.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147101389881.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147101402830.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471015261203.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147101542358.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471015691475.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147101679419.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471017051021.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147101723154.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147101782692.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041471019081418.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147101931114.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147101932141.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201132447.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201170222.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201197258.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201211448.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201271210.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201304503.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201358134.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414720135959.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201403526.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201511326.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414720157799.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201608301.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201668839.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201669167.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201694290.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201704248.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201710494.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201725197.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201727195.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201734220.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201808233.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201826520.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201896371.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147201923544.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414720199123.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041473011093713.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041473011112525.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041473011117419.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301114921.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301116678.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041473011171520.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041473011234563.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301145961.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301210414.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301213288.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301256354.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301282493.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301324266.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301454982.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041473015921076.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041473016231032.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301722410.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301730426.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301749491.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301754566.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414730182284.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301835817.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414730188456.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301905237.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301929247.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147301955308.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041474011022922.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041474011054756.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041474011083356.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041474011092876.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414740111381015.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414740111571077.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041474011169329.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414740111931038.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041474011199788.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414740112411237.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401143669.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401181608.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041474012311265.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401291580.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401320916.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401323830.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041474013311267.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401336782.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401403568.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401434504.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401437335.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401463902.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041474014641156.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401522702.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401531451.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401582783.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401586351.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401604678.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041474016461296.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401704867.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401723235.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041474017651065.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401790833.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401816288.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401869835.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401871208.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401876497.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041474019161201.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041474019411321.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041474019451124.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147401996597.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041475011001776.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414750110491489.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414750110901177.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414750111071472.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041475011197985.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414750112051077.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414750112621334.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414750112661048.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041475011266919.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414750114181421.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414750114471533.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414750114761381.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414750115191372.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041475011891454.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147501239641.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147501378984.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041475015581542.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041475016801451.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041475017601056.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147501767683.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041475017781285.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041475017931235.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041475018021393.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041475018171177.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041475018601381.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041475018661015.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041475019331417.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147501945281.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041475019581257.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041475019931380.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476011066968.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414760110771026.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414760110891058.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476011137605.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476011336945.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476011369876.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476011574211.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476011585402.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414760116771362.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476011686378.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476011733107.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476012231036.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476013721585.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476013931612.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476014181335.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476015711595.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476015811153.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476016281511.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476017341469.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041476018771471.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414770110171329.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041477011170152.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041477011254214.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041477011255265.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041477011275990.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041477011303166.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041477011335886.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041477011474236.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041477011479685.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041477011485610.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414770115721258.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147701197323.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147701300812.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041477013331269.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414770140490.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041477014111408.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041477015271606.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147701568768.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041477016411600.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041477016491600.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041477016601202.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041477017111183.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147701987508.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801108976.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801114518.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801147751.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801163773.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801191258.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801197686.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801240864.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801268867.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801274750.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801278748.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801313737.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801356618.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801371429.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801399264.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801451385.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801461823.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801518540.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801534768.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801580184.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041478015861025.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414780183586.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414780185233.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147801876520.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414790111231295.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414790111921372.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041479011195199.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041479011213319.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414790112521312.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414790113831490.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414790114681739.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414790115081686.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414790115221141.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414790115391445.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414790117381720.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414790117401495.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041479011750180.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414790117931518.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414790118041231.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414790118221569.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041479011823180.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414790118321613.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041479011851821.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041479011852242.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041479013521827.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041479014051406.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041479014371526.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147901565231.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041479015661363.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041479016021350.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041479016351481.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147901668320.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147901828555.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147901835558.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147901862167.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147901874176.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041479019491824.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004147901976241.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041479019851491.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041480011039364.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041480011072444.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414800110731022.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414800111241877.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041480011132884.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414800112511012.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041480011368485.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414800114261146.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041480011429471.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041480011482209.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041480011528267.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041480011556138.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414800115651854.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414800115821440.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414800115931053.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041480011601751.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041480011855178.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414800118951168.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414800119062186.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414800119431826.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041480012016881.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414800120462212.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414800121251203.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414800122201325.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148001284263.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041480013971862.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148001435951.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148001472888.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041480014891788.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041480015581836.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041480016681503.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148001669330.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041480016851738.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148001723797.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148001790483.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148001810399.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148001867686.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148001923259.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414810110091291.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414810110101358.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414810110221230.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414810110371273.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414810111041946.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481011211637.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481011236918.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414810112691544.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414810113461095.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481011347143.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414810114301079.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414810114941755.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414810116222013.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414810116681889.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481011715797.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414810117542048.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481011809718.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414810118101131.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481011842263.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414810119311915.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481011975296.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414810120221795.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481012024431.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481012901992.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148101312953.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481013432045.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148101445614.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481014851816.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481016021019.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148101608260.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148101638232.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481016541387.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148101660661.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481016911584.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148101775412.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481017961510.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481018691132.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148101909208.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041481019441644.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414820111171390.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041482011220974.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041482011232306.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414820113061023.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041482011316285.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041482011345199.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414820114021935.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414820115621172.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414820115951746.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041482011609250.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414820116481417.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414820116531164.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041482011722696.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041482011730119.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041482011760926.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041482011770739.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414820117761215.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041482011787337.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041482011822867.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041482011825379.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041482011911817.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148201288483.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148201296231.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148201371330.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041482014661476.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148201477893.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148201674877.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148201758895.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041482017861012.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148201864343.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414830113551251.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041483011428138.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041483011430614.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414830114461206.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041483011661340.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041483011698660.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148301447643.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041483014481098.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148301580464.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041483018161740.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148301980196.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041484011062488.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414840110911556.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414840110921369.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414840111731365.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148401117397.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414840112131479.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041484011226795.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041484011243411.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414840112571524.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414840114621137.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041484011618880.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414840122295.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041484012281561.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041484014571533.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148401482937.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148401485309.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148401497377.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148401509782.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148401572454.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148401615321.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041484017791244.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148401926926.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148401961582.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148401989340.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041485011015625.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414850110331028.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414850111021065.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414850111051052.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414850113261148.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414850113331170.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414850113381195.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414850114361120.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414850114381203.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041485011492223.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148501166543.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041485011821261.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041485011991282.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041485012051235.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041485012461316.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148501259889.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041485015411112.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041485015421459.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148501630542.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041485016521336.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148501699398.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041485017071019.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041485018011090.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148501871436.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/42004148501900993.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041486011045524.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041486011118471.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041486011354308.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041486011394428.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041486011404466.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/420041486011405482.jpg
#   inflating: /content/All_Labels_4000_Three/Algae/EAM_DHC/4200414860115061644.jpg
# ...
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147201926885.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147201947867.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041473011124397.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041473011175123.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041473011234180.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414730131780.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041473013461091.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041473013481236.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147301529285.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147301813924.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041474011017391.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041474011050120.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147401633695.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147401899225.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147401899239.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041475011015181.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041475011067288.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041475011222784.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147501130251.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041475011404640.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041475011483541.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041475012331212.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147501536229.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041476011661765.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147601169247.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147601194465.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147601371324.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147601441294.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147601649223.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041476019421073.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414770110501474.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041477011059289.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041477011086401.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041477011108379.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041477011161171.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147701357597.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147701878273.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147701918235.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414780110111119.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041478011043693.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147801169611.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041478012541001.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147801301525.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147801343133.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147801460107.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147801514122.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147801648761.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147801667889.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147801697177.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147801751436.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414780180280.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147801804571.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147801914398.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147801914404.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147801916397.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147801940129.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041478019461011.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147801953590.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041479011529100.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041479011782546.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041479012461404.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041479012491569.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041479014231100.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147901432992.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004147901561894.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041479016341083.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414800113031997.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414800115082131.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414800115662109.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041480011574493.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148001231406.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148001351761.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148001352459.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148001392700.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148001499820.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414810110161991.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414810111131686.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414810113641715.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041483011444923.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148301770162.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041484011059266.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041484011092271.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414840113261442.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414840113631366.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041484011367627.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414840115361529.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041484011541527.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414840116411453.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148401883480.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414850113201265.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414850113961257.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041485011477931.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414860110431114.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414860110981217.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414860111811193.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041486011203943.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414860113021047.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414860113971451.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414860114191225.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414860114191384.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414860114501253.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041486013191195.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148601393806.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148601766576.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148601768491.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148601803557.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041486018701174.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041486019991088.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041488011651136.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041488012091212.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148801251974.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041488012521160.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148801378691.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148801516676.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148801566730.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148801627201.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148801636310.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041489011018624.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414890111431194.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414890111501067.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200414890114601108.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041489012661259.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041489015481277.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420041489015741081.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42004148901696985.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008136501453201.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008136501595178.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420081367016281904.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420081367018661880.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008136801212877.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008136801443847.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008136801585576.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200813700110781424.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200813710112121325.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200813710112701259.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200813720252440.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008137202680385.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008137202869308.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008137202938700.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008137301252520.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008137301865993.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200813750116491204.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420081377011035718.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420081377011074890.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420081377012671063.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008137701445991.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008137701478647.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008137701517154.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008137701572977.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008137701842968.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008137701864306.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008137701948616.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008137701954618.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008138501665241.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008138501669229.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008138501760253.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420081386011477314.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008138801823415.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008139101880571.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008139201288926.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/420081392013701159.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008139201373885.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008139201378870.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008139201649708.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008139201662595.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42008139201772256.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200813920187674.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42009077101786104.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42009077201110250.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42009077401129942.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42009077802427825.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42009078001950946.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42009078101671671.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/4200907820111161159.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42009078401292303.jpg
#   inflating: /content/All_Labels_4000_Three/Soft Coral/SINV_SFC_O/42009078901585530.jpg

# %%
#Import Statements
import numpy as np
import math
import matplotlib.pyplot as plt
import torchvision
import torch
from torchvision import datasets, transforms
from torch.utils.data import random_split
import torch.nn as nn
import torchvision.models as models
from tqdm import tqdm
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

# %%
#First, we define our data loader.
#Much of this is from HW6
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform
    def __getitem__(self, index):
        x, y = self.subset[index]
        if self.transform:
            x = self.transform(x)
        return x, y
    def __len__(self):
        return len(self.subset)
def prepare_and_get_loaders(validation_split, batch_size, num_workers, dir_path):
    """
    This function loads and partitions our image data.

    val_split: proportion of the data that will be in the validation split
    batch_size: size of batches
    num_workers: number of parallel processors
    dir_path: directory path of the data
    """

    #Transforms to apply to training and test data
    data_transforms = {
        'train': transforms.Compose([
        #transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
        transforms.Resize((244, 244)),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ]),

        'test': transforms.Compose([
            transforms.Resize((244,244)),
            transforms.ToTensor(),
            transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
        ])
    }
    full_dataset = datasets.ImageFolder(dir_path)
    #WE ALSO NEED TO GET THE SUBCLASSESSSSSS BRUHHHH
    class_to_idx = full_dataset.class_to_idx

    m = len(full_dataset)
    val_size = int(validation_split * m)
    train_size = m - val_size

    train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])
    train_dataset = MyDataset(train_dataset, transform=data_transforms['train'])
    val_dataset = MyDataset(val_dataset, transform=data_transforms['test'])

    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)

    return train_loader, val_loader, class_to_idx

# %%
#This is finetune for when we have all the labels
### ALL LABELSSS ####

def finetune(model, train_loader, val_loader, learning_rate, num_epochs, L2, momentum1, momentum2, stepsize, gamma, class_to_idx):
    """

    Finetunes the given model on the loader data, and returns the trained model as well as the losses
    and final validation accuracy for plotting.

    model: the Pytorch model
    train_loader: the loader for the training data
    val_loader: the loader for the validation data
    learning_rate: alpha, the learning rate
    num_epochs: the number of epochs to train for
    L2: the L2 regularization value
    momentum1: the first momentum value
    momentum2: the second momentum value
    stepsize: the number of epochs between lowering the learning rate
    gamma: the ratio to multiply the learning rate at each step size

    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"My Device is {device}")
    model = model.to(device)

    criterion = nn.CrossEntropyLoss()

    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=L2, betas = (momentum1, momentum2))

    scheduler = StepLR(optimizer, step_size=stepsize, gamma=gamma)

    hist = {'train': [], 'val': []} # History of training and validation losses

    for epoch in tqdm(range(num_epochs), desc = "Training Epoch: "):
        model.train() #Training mode
        total_loss = 0.0
        for inputs, labels in train_loader:
            #put stuff on device
            inputs = inputs.to(device)
            labels = labels.to(device)

            #zero optimizer
            optimizer.zero_grad()

            #get outputs + train
            outputs = model(inputs)

            #get loss and do backward
            loss = criterion(outputs, labels)
            loss.backward()

            #step
            optimizer.step()

            total_loss += loss.item()

            # Free memory
            if device == "cuda":
              del inputs, labels, outputs, loss

        avg_train_loss = total_loss / len(train_loader)
        hist['train'].append(avg_train_loss)

        #Validation Mode Now
        model.eval()
        total_loss = 0.0

        #keep track of correct labels so we can get the val accuracy
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                #put on device
                inputs = inputs.to(device)
                labels = labels.to(device)

                #get outputs
                outputs = model(inputs)

                #get loss
                loss = criterion(outputs, labels)
                total_loss += loss.item()

                #https://www.digitalocean.com/community/tutorials/pytorch-torch-max
                max_element, predicted = torch.max(outputs, 1)
                total += labels.size(0)

                #Need some extra code to calculate correct


                labels_mapped = map_labels_to_larger_classes(labels, class_to_idx)
                predicted_mapped = map_labels_to_larger_classes(predicted, class_to_idx)


                #correct += (labels_mapped == predicted_mapped).sum().item()

                correct_predictions = sum(1 for true, pred in zip(labels_mapped, predicted_mapped) if true == pred)
                correct += correct_predictions

                # Free memory
                if device == "cuda":
                  del inputs, labels, outputs, loss

        avg_val_loss = total_loss / len(val_loader)
        hist['val'].append(avg_val_loss)
        val_accuracy = 100 * correct / total
        print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%')
        scheduler.step()

        if device == "cuda":
          torch.cuda.empty_cache() #cuda memory was filling up
    #final val accuracy
    final_val_accuracy = 100*correct/total

    return model, hist, final_val_accuracy

def map_labels_to_larger_classes(labels, class_to_idx):
    """
    Maps the given subclass labels to their corresponding larger class labels.
    """

    idx_to_class = {v: k for k, v in class_to_idx.items()}

    ALGAE_LABELS = ["CAL_CCA_DC", "EAM_DHC", "EAM_RB", "MACR_Cal_H", "MACR_Cal_P", "MACR_Fol_B", "MACR_Fol_F", "MACR_Fol_P", "Unc"]
    HARD_LABELS = ["BRA_ARB_Ac", "BRA_DIG_Ac", "BRA_OTH", "BRA_RND_St", "BRA_SMO_Po", "BRA_TAB-Ac", "BRA_VER_Po",
                    "MASE_LRG_I", "MASE_LRG_O", "MASE_MEA_L", "MASE_MEA_O", "MASE_SML_O", "MASE_SMO_P", "TFP_RDG_Al", "TFP_RND_Al"]
    SOFT_LABELS = ["NON_HEL", "SINV_SFC_A", "SINV_SFC_O"]


    subclass_to_larger_class = {label: "Algae" for label in ALGAE_LABELS}
    subclass_to_larger_class.update({label: "Hard Coral" for label in HARD_LABELS})
    subclass_to_larger_class.update({label: "Soft Coral" for label in SOFT_LABELS})

    # Map each label index to the larger class name
    mapped_labels = []
    for label_idx in labels:
        class_name = idx_to_class.get(label_idx.item())
        if not class_name:
            print(f"Warning: Label index {label_idx.item()} is not in idx_to_class mapping. Skipping this label.")
            continue

        larger_class_name = subclass_to_larger_class.get(class_name)
        if not larger_class_name:
            print(f"Warning: Subclass name '{class_name}' is not in subclass to larger class mapping. Skipping this label.")
            continue

        mapped_labels.append(larger_class_name)

    return mapped_labels

# %%
def load_model(arch, dropout, num_classes):
    """

    Loads a pretrained model, but with the final output layer removed and replaced with a randomly
    initialized output layer that will classify among the 5 buildings.

    """

    #select the model we want
    if arch == "resnet18":
        model = models.resnet18(weights="ResNet18_Weights.DEFAULT")
        num_ftrs = model.fc.in_features
        model.fc = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "resnet34":
        model = models.resnet34(weights="DEFAULT")
        num_ftrs = model.fc.in_features
        model.fc = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "mobile":
        model = models.mobilenet_v2(weights="MobileNet_V2_Weights.DEFAULT")
        num_ftrs = model.classifier[1].in_features
        model.classifier = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "alexnet":
            model = models.alexnet(weights="AlexNet_Weights.DEFAULT")
            num_ftrs = model.classifier[1].in_features
            model.classifier[6] = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "vgg16":
        model = models.vgg16(weights="VGG16_Weights.DEFAULT")
        num_ftrs = model.classifier[0].in_features
        model.classifier[6] = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "densenet":
        model = models.densenet121(weights="DenseNet121_Weights.DEFAULT")
        num_ftrs = model.classifier.in_features
        model.classifier = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "inception":
        model = models.inception_v3(weights="Inception_V3_Weights.DEFAULT")
        num_ftrs = model.fc.in_features
        model.fc = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "efficientnet":
        model = models.efficientnet_b0(weights="EfficientNet_B0_Weights.DEFAULT")
        num_ftrs = model.classifier[1].in_features
        model.classifier = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "googlenet":
        model = models.googlenet(weights="GoogLeNet_Weights.DEFAULT")
        num_ftrs = model.fc.in_features
        model.fc = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "squeezenet":
        model = models.squeezenet1_0(weights="SqueezeNet1_0_Weights.DEFAULT")
        model.classifier[1] = nn.Conv2d(512, num_classes, kernel_size=(1,1), stride=(1,1))
        model.num_classes = num_classes

    else:
        print("Incorrect model Architecture selected")
        raise

    return model

# %%
#Dataset parameters
validation_split = 0.2
batch_size = 64
num_workers = 2
dir_path = "Data"

train_loader, val_loader, class_to_idx = prepare_and_get_loaders(validation_split, batch_size, num_workers, dir_path)

# %%
 del model
 torch.cuda.empty_cache()

# %%
#Model Parameters
results = {}

for arch in ["googlenet"]:
    dropout = 0
    num_classes = 27
    model = load_model(arch, dropout, num_classes)

    #Finetuning Parameters
    learning_rate = 0.0001
    num_epochs = 5
    L2 = 0
    momentum1 = 0.99
    momentum2 = 0.9
    stepsize = 3
    gamma = 0.1
    model, hist, final_val_accuracy = finetune(model,
                                              train_loader,
                                              val_loader,
                                              learning_rate,
                                              num_epochs,
                                              L2,
                                              momentum1,
                                              momentum2,
                                              stepsize,
                                              gamma,
                                              class_to_idx)
    results[arch] = final_val_accuracy
    print(f"Our final validation accuracy accuracy using the full CNN is {final_val_accuracy:.2f}%")
    #TOOK AWAY THE COLORJITTER - basically the same
# Out:
# My Device is cuda
# Training Epoch:  20%|██        | 1/5 [00:16<01:07, 16.91s/it]
# Epoch [1/5], Training Loss: 2.3132, Validation Loss: 1.4182, Validation Accuracy: 69.82%
# Training Epoch:  40%|████      | 2/5 [00:34<00:51, 17.33s/it]
# Epoch [2/5], Training Loss: 1.2139, Validation Loss: 1.3942, Validation Accuracy: 70.60%
# Training Epoch:  60%|██████    | 3/5 [00:52<00:35, 17.70s/it]
# Epoch [3/5], Training Loss: 1.0328, Validation Loss: 1.1246, Validation Accuracy: 78.63%
# Training Epoch:  80%|████████  | 4/5 [01:09<00:17, 17.41s/it]
# Epoch [4/5], Training Loss: 0.9037, Validation Loss: 1.0846, Validation Accuracy: 78.63%
# Training Epoch: 100%|██████████| 5/5 [01:26<00:00, 17.28s/it]
# Epoch [5/5], Training Loss: 0.8696, Validation Loss: 1.0900, Validation Accuracy: 79.15%
# Our final validation accuracy accuracy using the full CNN is 79.15%

# %%
def plot_history(hist):
    epochs = range(1, len(hist['train']) + 1)

    # Plot training and validation loss
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, hist['train'], 'b', label='Training loss')
    plt.plot(epochs, hist['val'], 'r', label='Validation loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# %%
plot_history(hist)

# %%
import csv

# %%
class CleaningDataset(torch.utils.data.Dataset): #new dataset that also returns the path to the image
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform
    def __getitem__(self, index):
        x, y = self.subset[index]
        img_path = self.subset.imgs[index][0]
        if self.transform:
            x = self.transform(x)
        return x, y, img_path
    def __len__(self):
        return len(self.subset)



def cleaning_loader(dir_path):
    """
    This function makes our cleaning data loader, and we also need the class names for manual relabelling

    dir_path: directory path of the data
    """

    #Loading transform
    data_transforms = {
        'load': transforms.Compose([
            transforms.Resize((244,244)),
            transforms.ToTensor(),
            transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
        ])
    }
    full_dataset = datasets.ImageFolder(dir_path)
    class_names = full_dataset.classes

    load_dataset = CleaningDataset(full_dataset, transform=data_transforms['load'])

    clean_loader = torch.utils.data.DataLoader(load_dataset, shuffle=False, num_workers=0)

    return clean_loader, class_names



def unnormalize(tensor):
    mean = torch.tensor([0.485, 0.456, 0.406])
    std = torch.tensor([0.229, 0.224, 0.225])
    tensor = tensor * std[:, None, None] + mean[:, None, None]
    return tensor.clamp(0, 1) #have to be between 0 and 1



def get_misclassified_images(loader, model, class_names, confidence_threshold=0.1):
    model.eval()
    misclassified = []

    with torch.no_grad():
        for images, true_labels, paths in tqdm(iter(loader), desc="Evaluating"):
            outputs = model(images)
            probabilities = torch.nn.functional.softmax(outputs, dim=1)
            max_probs, predicted_labels = torch.max(probabilities, dim=1)

            for i in range(len(images)):
                if predicted_labels[i] != true_labels[i] and max_probs[i] > confidence_threshold:
                    misclassified.append({
                        'image': images[i],
                        'true_label': true_labels[i],
                        'predicted_label': predicted_labels[i],
                        'confidence': max_probs[i].item(),
                        'path': paths[i]
                    })

    # Sort in descending order cuz we wanna show the worst classified first
    misclassified.sort(key=lambda x: x['confidence'], reverse=True)
    return misclassified

def display_misclassified_images(misclassified_list, class_names, output_csv):
    # Initialize a dictionary to store misclassification counts
    misclassification_counts = {name: {other: 0 for other in class_names} for name in class_names}

    #Count misclassifications
    for item in misclassified_list:
        true_label_name = class_names[item['true_label']]
        predicted_label_name = class_names[item['predicted_label']]
        misclassification_counts[true_label_name][predicted_label_name] += 1

    #Print total number of misclassified images
    total_misclassified = len(misclassified_list)
    print(f"Total Misclassified Images: {total_misclassified}")

    # Print misclassification details
    for true_label, predictions in misclassification_counts.items():
        for predicted_label, count in predictions.items():
            if true_label != predicted_label and count > 0:
                print(f"True Label '{true_label}' predicted as '{predicted_label}': {count} times")

    # Create or open the CSV file
    with open(output_csv, 'w', newline='') as file:
        writer = csv.writer(file)
        # Write the header
        writer.writerow(['Filename', 'Original Label', 'Final Label'])

        #Displaying loop - USER INPUT FOR MODIFYING CSV
        for item in misclassified_list:
            img = unnormalize(item['image']).permute(1, 2, 0) #from hw6
            plt.imshow(img)
            plt.title(f"Filename: {item['path']}\nPredicted: {class_names[item['predicted_label']]}, Actual: {class_names[item['true_label']]}, Confidence: {item['confidence']:.2f}")
            plt.show()

            #We determine if relabelling
            response = input("Relabel this image? [y/n/c] (y: yes, n: no, c: custom label): ").strip().lower()
            final_label = item['true_label']
            if response == 'y':
                final_label = item['predicted_label']
            elif response == 'c':
                # Show available class names and take input
                print("Available classes: ", class_names)
                custom_label = input("Enter the custom label name: ").strip()
                if custom_label in class_names:
                    final_label = class_names.index(custom_label)
                else:
                    print("Invalid label name. Keeping the original label.")

            # Write to CSV
            writer.writerow([item['path'], class_names[item['true_label']], class_names[final_label]])

# %%
clean_loader, class_names = cleaning_loader(dir_path)
misclassified_images = get_misclassified_images(clean_loader, model, class_names)
csv_name = r"\Users\Brandon\Desktop\Classes\E208\Homework\E208_Final\output_labelling.csv"
display_misclassified_images(misclassified_images, class_names, csv_name)
# Out:
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 385/385 [00:14<00:00, 26.33it/s]
# Total Misclassified Images: 95
# True Label 'Algae' predicted as 'Hard Coral': 20 times
# True Label 'Algae' predicted as 'Soft Coral': 30 times
# True Label 'Hard Coral' predicted as 'Algae': 9 times
# True Label 'Hard Coral' predicted as 'Soft Coral': 13 times
# True Label 'Soft Coral' predicted as 'Algae': 6 times
# True Label 'Soft Coral' predicted as 'Hard Coral': 17 times
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_34252\1309171810.py in <module>
#       2 misclassified_images = get_misclassified_images(clean_loader, model, class_names)
#       3 csv_name = r"\Users\Brandon\Desktop\Classes\E208\Homework\E208_Final\output_labelling.csv"
# ----> 4 display_misclassified_images(misclassified_images, class_names, csv_name)
#
# ~\AppData\Local\Temp\ipykernel_34252\1821157672.py in display_misclassified_images(misclassified_list, class_names, output_csv)
#     106
#     107             #We determine if relabelling
# --> 108             response = input("Relabel this image? [y/n/c] (y: yes, n: no, c: custom label): ").strip().lower()
#     109             final_label = item['true_label']
#     110             if response == 'y':
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
