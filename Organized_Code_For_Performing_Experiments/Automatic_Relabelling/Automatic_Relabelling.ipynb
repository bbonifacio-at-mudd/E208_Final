# %% [markdown]
# # This is the Jupyter Notebook for the Iterative Data Cleaning Process

# %%
# !unzip /content/Cropped_Data_4000_Three.zip -d /content/
# Out:
# Archive:  /content/Cropped_Data_4000_Three.zip
#    creating: /content/Cropped_Data_4000_Three/Algae/
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041461011010173.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041461011091120.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041461011243323.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041461011253896.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041461011399166.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414610114801502.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414610116111778.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414610116611504.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146101311474.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146101399487.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041461017301695.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041462011017277.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146201108163.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414620112521391.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414620112771315.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414620116941414.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414620117461067.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414620117741752.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414620118421519.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414620118621670.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041462012701196.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146201591304.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146201609184.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146201710601.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146201797147.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146201898418.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146201946448.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146201955151.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146201961799.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414630110221070.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414630110341195.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041463011274464.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041463011313674.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146301171770.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146301209863.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146301272838.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146301312988.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146301326633.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146301362813.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041463014201014.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041463016291249.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146301701018.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146301730829.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414630177771.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146301990205.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146401138156.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146401376191.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146401426372.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146401455504.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146401498551.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146401518352.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146401553354.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146401569683.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146401643293.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146501123192.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146501129240.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146501171217.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146501172273.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146501206252.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414650120754.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146501275112.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146501319138.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146501546399.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414650158208.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146601113449.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041466011161194.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041466011175455.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146601124266.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146601212709.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146601224512.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146601411533.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146601421623.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146601486452.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146601498891.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146601683969.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146601722972.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146601743544.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146601796442.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041466018281173.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146601925305.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146601981384.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041467011278581.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414670113491698.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041467011366635.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041467011457374.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041467011606685.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041467011618713.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041467011619760.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414670119331177.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041467011962984.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041467012841740.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146701316360.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041467013411047.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146701347794.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146701358950.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041467013851028.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041467014221178.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146701508723.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146701538544.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146701547405.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146701783349.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041468011008909.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414680110601306.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414680111321117.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414680112141249.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041468012181351.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146801225523.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041468012341410.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146801367279.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146801383857.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041468018381037.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414690110221591.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414690110311544.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041469011084951.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041469011118997.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041469011120633.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041469011130284.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041469011421859.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041469011434283.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004146901154599.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041469011602924.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041469011694358.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041469011698873.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041469011784196.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041469011797875.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041469013141385.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041469016301036.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470011010140.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470011152643.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470011165707.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470011321187.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470011385122.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470011396438.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470011465187.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414700115031553.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470011509363.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470011534554.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470011537329.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414700115571302.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470011574852.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470011653216.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470011683621.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470011695309.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414700117461191.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470011854458.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470013601389.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041470014941337.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147001577264.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147001804396.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147001961303.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471011010148.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471011132559.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414710111551521.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471011239789.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471011257397.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471011300973.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471011371563.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471011411468.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471011417659.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471011488232.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471011489491.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147101159384.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471011761310.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471011891554.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147101274596.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147101293309.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147101366493.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471013761362.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147101385310.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471013871013.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147101389804.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147101389881.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147101402830.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471015261203.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147101542358.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471015691475.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147101679419.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471017051021.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147101723154.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471017691426.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147101782692.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471019081418.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147101931114.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147101932141.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041471019601324.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201132447.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201170222.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201197258.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201211448.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201271210.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201304503.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201358134.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414720135959.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201403526.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201511326.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414720157799.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201608301.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201668839.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201669167.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201694290.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201704248.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201710494.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201725197.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201727195.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201734220.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201808233.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201826520.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201896371.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147201923544.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414720199123.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041473011093713.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041473011112525.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041473011117419.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301114921.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301116678.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041473011171520.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041473011234563.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301145961.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301210414.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301213288.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301256354.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301282493.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301324266.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301454982.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041473015221110.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041473015921076.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041473016231032.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301722410.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301730426.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301749491.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301754566.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414730182284.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301835817.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414730188456.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301905237.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301929247.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301955308.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147301985467.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041474011022922.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041474011054756.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041474011083356.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041474011092876.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414740111381015.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414740111571077.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041474011169329.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414740111931038.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041474011199788.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414740112411237.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401143669.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401181608.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041474012311265.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401291580.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401320916.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401323830.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041474013311267.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401336782.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401403568.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401434504.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401437335.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401463902.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041474014641156.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401522702.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401531451.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401582783.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401586351.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401604678.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041474016461296.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401704867.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401723235.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041474017651065.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401790833.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401816288.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401869835.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401871208.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401876497.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041474019161201.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041474019411321.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041474019451124.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147401996597.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041475011001776.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414750110491489.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414750110901177.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414750111071472.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041475011197985.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414750112051077.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414750112621334.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414750112661048.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041475011266919.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414750114181421.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414750114471533.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414750114761381.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414750115191372.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041475011891454.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147501239641.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147501378984.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041475015581542.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041475016801451.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041475017601056.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147501767683.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041475017781285.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041475017931235.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041475018021393.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041475018171177.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041475018601381.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041475018661015.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041475019331417.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147501945281.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041475019581257.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041475019931380.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476011066968.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414760110771026.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414760110891058.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476011137605.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476011264248.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476011336945.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476011369876.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476011574211.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476011585402.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414760116771362.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476011686378.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476011733107.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476012231036.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476013721585.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476013931612.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476014181335.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476015711595.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476015811153.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476016281511.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476017341469.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041476018771471.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414770110171329.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041477011170152.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041477011254214.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041477011255265.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041477011275990.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041477011303166.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041477011335886.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041477011474236.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041477011479685.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041477011485610.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414770115721258.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147701197323.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147701300812.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041477013331269.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414770140490.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041477014111408.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041477015271606.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147701568768.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041477016411600.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041477016491600.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041477016601202.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041477017111183.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147701987508.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801108976.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801114518.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801147751.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801163773.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801191258.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801197686.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801240864.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801268867.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801274750.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801278748.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801313737.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801356618.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801371429.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801399264.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801451385.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801461823.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801518540.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801534768.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801580184.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041478015861025.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414780183586.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414780185233.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147801876520.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414790111231295.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414790111921372.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041479011195199.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041479011213319.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414790112521312.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414790113831490.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414790114681739.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414790115081686.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414790115221141.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414790115391445.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414790117381720.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414790117401495.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041479011750180.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414790117931518.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414790118041231.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414790118221569.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041479011823180.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414790118321613.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041479011851821.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041479011852242.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041479013521827.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041479014051406.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041479014371526.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147901565231.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041479015661363.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041479016021350.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041479016351481.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147901668320.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147901828555.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147901835558.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147901862167.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147901874176.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041479019491824.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004147901976241.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041479019851491.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041480011039364.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041480011072444.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414800110731022.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414800111241877.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041480011132884.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414800112511012.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041480011368485.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414800114261146.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041480011429471.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041480011482209.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041480011528267.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041480011556138.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414800115651854.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414800115821440.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414800115931053.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041480011601751.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041480011855178.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414800118951168.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414800119062186.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414800119431826.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041480012016881.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414800120462212.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414800121251203.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414800122201325.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148001284263.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041480013971862.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148001435951.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148001472888.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041480014891788.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041480015581836.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041480016681503.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148001669330.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041480016851738.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148001723797.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148001790483.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148001810399.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148001867686.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148001923259.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414810110091291.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414810110101358.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414810110221230.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414810110371273.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414810111041946.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481011211637.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481011236918.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414810112691544.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414810113461095.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481011347143.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414810114301079.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414810114941755.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414810116222013.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414810116681889.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481011715797.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414810117542048.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481011809718.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414810118101131.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481011842263.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414810119311915.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481011975296.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414810120221795.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481012024431.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481012901992.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148101312953.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481013432045.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148101445614.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481014851816.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481016021019.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148101608260.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148101638232.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481016541387.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148101660661.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481016911584.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148101775412.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481017961510.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481018691132.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148101909208.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041481019441644.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414820111171390.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041482011220974.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041482011232306.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414820113061023.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041482011316285.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041482011345199.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414820114021935.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414820115621172.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414820115951746.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041482011609250.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414820116481417.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414820116531164.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041482011722696.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041482011730119.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041482011760926.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041482011770739.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414820117761215.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041482011787337.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041482011822867.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041482011825379.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041482011911817.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148201288483.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148201296231.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148201371330.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041482014661476.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148201477893.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148201674877.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148201758895.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041482017861012.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148201864343.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414830113551251.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041483011428138.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041483011430614.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414830114461206.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041483011661340.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041483011698660.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148301447643.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041483014481098.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148301580464.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041483018161740.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148301980196.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041484011062488.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414840110911556.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414840110921369.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414840111731365.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148401117397.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414840112131479.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041484011226795.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041484011243411.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414840112571524.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414840114621137.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041484011618880.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414840122295.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041484012281561.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041484014571533.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148401482937.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148401485309.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148401497377.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148401509782.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148401572454.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148401615321.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041484017791244.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148401926926.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148401961582.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148401989340.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041485011015625.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414850110331028.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414850111021065.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414850111051052.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041485011299479.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414850113261148.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414850113331170.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414850113381195.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414850114361120.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414850114381203.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041485011492223.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148501166543.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041485011821261.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041485011991282.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041485012051235.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041485012461316.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148501259889.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041485015411112.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041485015421459.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148501630542.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041485016521336.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148501699398.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041485017071019.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041485018011090.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148501871436.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148501900993.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041486011045524.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041486011118471.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041486011354308.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041486011394428.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041486011404466.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041486011405482.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414860115061644.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041486011529465.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041486011650630.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148601334527.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041486013371237.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041486013921583.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148601499367.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148601546337.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041486016311616.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148601648827.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148601676835.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148601697910.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/420041486017791579.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701110905.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701151929.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701184197.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701240164.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701256810.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701285638.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701312823.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701343394.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701363824.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701377468.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701382744.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414870141874.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701434459.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701435155.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701457718.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701483808.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701500537.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701543633.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701599525.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701607920.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414870163880.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701641806.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701677459.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/4200414870172260.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701746452.jpg
#   inflating: /content/Cropped_Data_4000_Three/Algae/42004148701800582.jpg
# ...
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041474011017391.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041474011050120.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147401633695.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147401899225.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147401899239.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041475011015181.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041475011067288.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041475011222784.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147501130251.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041475011404640.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041475011483541.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041475012331212.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147501536229.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041476011661765.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147601169247.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147601194465.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147601371324.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147601441294.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147601649223.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041476019421073.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414770110501474.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041477011059289.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041477011086401.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041477011108379.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041477011161171.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147701357597.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147701878273.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147701918235.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414780110111119.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041478011043693.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147801169611.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041478012541001.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147801301525.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147801343133.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147801460107.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147801514122.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147801648761.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147801667889.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147801697177.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147801751436.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414780180280.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147801804571.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147801914398.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147801914404.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147801916397.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147801940129.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041478019461011.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147801953590.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041479011529100.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041479011782546.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041479012461404.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041479012491569.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041479014231100.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147901432992.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004147901561894.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041479016341083.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414800113031997.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414800115082131.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414800115662109.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041480011574493.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148001231406.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148001351761.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148001352459.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148001392700.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148001499820.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414810110161991.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414810111131686.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414810113641715.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041483011444923.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148301770162.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041484011059266.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041484011092271.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414840113261442.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414840113631366.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041484011367627.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414840115361529.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041484011541527.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414840116411453.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148401883480.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414850113201265.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414850113961257.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041485011477931.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414860110431114.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414860110981217.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414860111811193.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041486011203943.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414860113021047.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414860113971451.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414860114191225.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414860114191384.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414860114501253.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041486013191195.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148601393806.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148601766576.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148601768491.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148601803557.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041486018701174.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041486019991088.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041488011651136.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041488012091212.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148801251974.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041488012521160.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148801378691.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148801516676.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148801566730.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148801627201.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148801636310.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041489011018624.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414890111431194.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414890111501067.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200414890114601108.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041489012661259.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041489015481277.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420041489015741081.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42004148901696985.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008136501453201.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008136501595178.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420081367016281904.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420081367018661880.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008136801212877.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008136801443847.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008136801585576.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200813700110781424.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420081370016721572.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200813710112121325.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200813710112701259.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200813720252440.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008137202680385.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008137202869308.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008137202938700.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008137301252520.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008137301698916.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008137301865993.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200813740110531019.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200813740111351207.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420081374011232981.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200813750116371272.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200813750116491204.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420081377011035718.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420081377011074890.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420081377012671063.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008137701445991.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008137701478647.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008137701517154.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008137701572977.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008137701842968.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008137701864306.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008137701948616.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008137701954618.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008138501665241.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008138501669229.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008138501760253.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420081386011477314.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008138801823415.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008139001971813.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008139101880571.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008139201288926.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420081392013701159.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008139201373885.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008139201378870.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008139201649708.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008139201662595.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008139201772256.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200813920187674.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008139501114116.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42008139501187150.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009077101786104.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009077101921597.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009077201110250.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009077301149734.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009077401129942.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420090777011021275.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009077802427825.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420090779011135150.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420090779012671240.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009077901298598.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009077901309542.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009077901324609.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009077901521463.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009078001328222.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009078001346884.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009078001950946.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009078101194496.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009078101390131.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009078101671671.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/4200907820111161159.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009078401292303.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009078501263362.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009078801114221.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420090789011861231.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009078901218847.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009078901369850.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009078901427722.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/42009078901585530.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420090790011045810.jpg
#   inflating: /content/Cropped_Data_4000_Three/Soft Coral/420090790011084829.jpg

# %%
#Import Statements
import numpy as np
import math
import matplotlib.pyplot as plt
import torchvision
import torch
from torchvision import datasets, transforms
from torch.utils.data import random_split
import torch.nn as nn
import torchvision.models as models
from tqdm import tqdm
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
# !pip install timm
import timm
import os
import csv
import shutil
import random
# Out:
# Collecting timm
#   Downloading timm-0.9.12-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.16.0+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.19.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (4.66.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.23.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm) (1.3.0)
# Installing collected packages: timm
# Successfully installed timm-0.9.12

# %%
#This is one big cell of all the helper functions we need

class MyDataset(torch.utils.data.Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform
    def __getitem__(self, index):
        x, y = self.subset[index]
        if self.transform:
            x = self.transform(x)
        return x, y
    def __len__(self):
        return len(self.subset)
def prepare_and_get_loaders(validation_split, batch_size, num_workers, dir_path):
    """
    This function loads and partitions our image data.

    val_split: proportion of the data that will be in the validation split
    batch_size: size of batches
    num_workers: number of parallel processors
    dir_path: directory path of the data
    """

    #Transforms to apply to training and test data
    data_transforms = {
        'train': transforms.Compose([
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ]),

        'test': transforms.Compose([
            transforms.Resize((224,224)),
            transforms.ToTensor(),
            transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
        ])
    }
    full_dataset = datasets.ImageFolder(dir_path)

    m = len(full_dataset)
    val_size = int(validation_split * m)
    train_size = m - val_size

    train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])
    train_dataset = MyDataset(train_dataset, transform=data_transforms['train'])
    val_dataset = MyDataset(val_dataset, transform=data_transforms['test'])

    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)

    return train_loader, val_loader

def finetune(model, train_loader, val_loader, learning_rate, num_epochs, L2, momentum1, momentum2, stepsize, gamma):
    """

    Finetunes the given model on the loader data, and returns the trained model as well as the losses
    and final validation accuracy for plotting.

    model: the Pytorch model
    train_loader: the loader for the training data
    val_loader: the loader for the validation data
    learning_rate: alpha, the learning rate
    num_epochs: the number of epochs to train for
    L2: the L2 regularization value
    momentum1: the first momentum value
    momentum2: the second momentum value
    stepsize: the number of epochs between lowering the learning rate
    gamma: the ratio to multiply the learning rate at each step size

    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"My Device is {device}")
    model = model.to(device)

    criterion = nn.CrossEntropyLoss()

    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=L2, betas = (momentum1, momentum2))

    scheduler = StepLR(optimizer, step_size=stepsize, gamma=gamma)

    hist = {'train': [], 'val': []} # History of training and validation losses

    for epoch in tqdm(range(num_epochs), desc = "Training Epoch: "):
        model.train() #Training mode
        total_loss = 0.0
        for inputs, labels in train_loader:
            #put stuff on device
            inputs = inputs.to(device)
            labels = labels.to(device)

            #zero optimizer
            optimizer.zero_grad()

            #get outputs + train
            outputs = model(inputs)

            #get loss and do backward
            loss = criterion(outputs, labels)
            loss.backward()

            #step
            optimizer.step()

            total_loss += loss.item()

            # Free memory
            if device == "cuda":
              del inputs, labels, outputs, loss

        avg_train_loss = total_loss / len(train_loader)
        hist['train'].append(avg_train_loss)

        #Validation Mode Now
        model.eval()
        total_loss = 0.0

        #keep track of correct labels so we can get the val accuracy
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                #put on device
                inputs = inputs.to(device)
                labels = labels.to(device)

                #get outputs
                outputs = model(inputs)

                #get loss
                loss = criterion(outputs, labels)
                total_loss += loss.item()

                #https://www.digitalocean.com/community/tutorials/pytorch-torch-max
                max_element, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                # Free memory
                if device == "cuda":
                  del inputs, labels, outputs, loss

        avg_val_loss = total_loss / len(val_loader)
        hist['val'].append(avg_val_loss)
        val_accuracy = 100 * correct / total
        print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%')
        scheduler.step()

        if device == "cuda":
          torch.cuda.empty_cache() #cuda memory was filling up
    #final val accuracy
    final_val_accuracy = 100*correct/total

    return model, hist, final_val_accuracy

def load_model(arch, dropout, num_classes):
    """

    Loads a pretrained model, but with the final output layer removed and replaced with a randomly
    initialized output layer that will classify among the coral.

    """

    #select the model we want
    if arch == "resnet18":
        model = models.resnet18(weights="ResNet18_Weights.DEFAULT")
        num_ftrs = model.fc.in_features
        model.fc = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "resnet34":
        model = models.resnet34(weights="DEFAULT")
        num_ftrs = model.fc.in_features
        model.fc = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "mobile":
        model = models.mobilenet_v2(weights="MobileNet_V2_Weights.DEFAULT")
        num_ftrs = model.classifier[1].in_features
        model.classifier = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "alexnet":
            model = models.alexnet(weights="AlexNet_Weights.DEFAULT")
            num_ftrs = model.classifier[1].in_features
            model.classifier[6] = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "vgg16":
        model = models.vgg16(weights="VGG16_Weights.DEFAULT")
        num_ftrs = model.classifier[0].in_features
        model.classifier[6] = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "densenet":
        model = models.densenet121(weights="DenseNet121_Weights.DEFAULT")
        num_ftrs = model.classifier.in_features
        model.classifier = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "inception":
        model = models.inception_v3(weights="Inception_V3_Weights.DEFAULT")
        num_ftrs = model.fc.in_features
        model.fc = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "efficientnet":
        model = models.efficientnet_b0(weights="EfficientNet_B0_Weights.DEFAULT")
        num_ftrs = model.classifier[1].in_features
        model.classifier = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "googlenet":
        model = models.googlenet(weights="GoogLeNet_Weights.DEFAULT")
        num_ftrs = model.fc.in_features
        model.fc = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "squeezenet":
        model = models.squeezenet1_0(weights="SqueezeNet1_0_Weights.DEFAULT")
        model.classifier[1] = nn.Conv2d(512, num_classes, kernel_size=(1,1), stride=(1,1))
        model.num_classes = num_classes

    elif arch == "vit":
        model = timm.create_model('vit_base_patch16_224', pretrained=True)
        num_ftrs = model.head.in_features
        model.head = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))
    elif arch == "deit":
        model = timm.create_model('deit_base_patch16_224', pretrained=True)
        num_ftrs = model.head.in_features
        model.head = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "mixer":
        model = timm.create_model('mixer_b16_224', pretrained=True)
        num_ftrs = model.head.in_features
        model.head = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))

    elif arch == "tnt":
        model = timm.create_model('tnt_s_patch16_224', pretrained=True)
        num_ftrs = model.head.in_features
        model.head = nn.Sequential(nn.Dropout(dropout), nn.Linear(num_ftrs, num_classes))
    else:
        print("Incorrect model Architecture selected")
        raise

    return model


def plot_history(hist):
    epochs = range(1, len(hist['train']) + 1)

    # Plot training and validation loss
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, hist['train'], 'b', label='Training loss')
    plt.plot(epochs, hist['val'], 'r', label='Validation loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()


def plot_label_history(label_accuracy_history, validation_accuracies, title = None):
    epochs = range(0, len(label_accuracy_history))

    # Plot training and validation loss
    plt.figure(figsize=(12, 6))
    plt.plot(epochs, label_accuracy_history, 'b', label = "Label Accuracies")
    plt.plot(epochs, validation_accuracies, 'r', label = "Val Accuracies")
    if not title:
      plt.title('Accuracies vs. Iteration')
    else:
      plt.title(title)
    plt.xlabel('Iteration')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.show()


def create_labels_csv(data_dir, csv_filename):
    """
    Create a CSV file of the label, name, and also the path of the images in a particular directory
    without editing the images.

    data_dir: Directory containing the images organized by label.
    csv_filename: Path to the CSV file to be created. Can also overwrite
    """

    with open(csv_filename, mode='w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(['image_path', 'image_name', 'label'])

        for label in os.listdir(data_dir):
            label_dir = os.path.join(data_dir, label)
            if os.path.isdir(label_dir):
                for image_file in os.listdir(label_dir):
                    image_path = os.path.join(label_dir, image_file)
                    image_name = os.path.basename(image_path)
                    csv_writer.writerow([image_path, image_name, label])

    print(f"CSV file created at {csv_filename}")

def create_dirty_data(original_dir, dirty_dir, x):
    """
    Create a dataset with x% of the data having randomized labels,
    while the rest retain their original labels.

    original_dir: The directory of the original dataset.
    dirty_dir: The directory to store the dirty dataset.
    x: The proportion of the dataset to be made 'dirty' (0 < x < 1).
    """

    print("Deleting Dirty Data Directory")
    if os.path.exists(dirty_dir):
        shutil.rmtree(dirty_dir)
    print("Writing Dirty Data Directory")
    # Create the dirty directory
    os.makedirs(dirty_dir)

    # Get all image paths and their labels
    images = []
    for class_name in os.listdir(original_dir):
        class_dir = os.path.join(original_dir, class_name)
        if os.path.isdir(class_dir):
            images.extend([(os.path.join(class_dir, img), class_name) for img in os.listdir(class_dir)])

    # Randomly select a subset of images to be 'dirty'
    num_dirty = int(len(images) * x)
    dirty_data = set(random.sample(images, num_dirty))

    # Copy images to the new directory
    class_names = os.listdir(original_dir)

    for img_path, label in tqdm(images, desc="Writing Data"):
        if (img_path, label) in dirty_data:
            # Randomize label for dirty data
            new_label = random.choice(class_names)
        else:
            new_label = label

        new_path = os.path.join(dirty_dir, new_label, os.path.basename(img_path))
        os.makedirs(os.path.dirname(new_path), exist_ok=True)
        shutil.copy(img_path, new_path)


def calculate_label_accuracy(clean_csv, dirty_csv):
    """
    Calculate the label accuracy of the dirty dataset compared to the clean dataset.

    clean_csv: Path to the CSV file with the original (clean) labels.
    dirty_csv: Path to the CSV file with the dirty labels.
    """

    # Read the CSV files and store labels in dictionaries
    clean_labels = {}
    dirty_labels = {}

    with open(clean_csv, mode='r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            clean_labels[row['image_name']] = row['label']

    with open(dirty_csv, mode='r') as file:
        reader = csv.DictReader(file)
        for row in reader:
            dirty_labels[row['image_name']] = row['label']

    # Compare labels and calculate accuracy
    correct = 0
    total = len(dirty_labels)

    for image_name, label in dirty_labels.items():
        if image_name not in clean_labels:
            print("Image not found!")
        if clean_labels[image_name] == label:
            correct += 1

    accuracy = correct / total if total > 0 else 0
    return accuracy



class CleaningDataset(torch.utils.data.Dataset): #new dataset that also returns the path to the image
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform
    def __getitem__(self, index):
        x, y = self.subset[index]
        img_path = self.subset.imgs[index][0]
        if self.transform:
            x = self.transform(x)
        return x, y, img_path
    def __len__(self):
        return len(self.subset)



def cleaning_loader(dir_path):
    """
    This function makes our cleaning data loader, and we also need the class names for manual relabelling

    dir_path: directory path of the data
    """

    #Loading transform
    data_transforms = {
        'load': transforms.Compose([
            transforms.Resize((224,224)),
            transforms.ToTensor(),
            transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
        ])
    }
    full_dataset = datasets.ImageFolder(dir_path)
    class_names = full_dataset.classes

    load_dataset = CleaningDataset(full_dataset, transform=data_transforms['load'])
    clean_loader = torch.utils.data.DataLoader(load_dataset, shuffle=False, num_workers=0)

    return clean_loader, class_names




def get_misclassified_images(loader, model, class_names, confidence_threshold):
    model.eval()
    misclassified = []

    with torch.no_grad():
        for images, true_labels, paths in tqdm(iter(loader), desc="Evaluating"):
            images = images.to('cuda')
            outputs = model(images)
            probabilities = torch.nn.functional.softmax(outputs, dim=1)
            max_probs, predicted_labels = torch.max(probabilities, dim=1)

            for i in range(len(images)):
                if predicted_labels[i] != true_labels[i] and max_probs[i] > confidence_threshold:
                    misclassified.append({
                        'image': images[i],
                        'true_label': true_labels[i],
                        'predicted_label': predicted_labels[i],
                        'confidence': max_probs[i].item(),
                        'path': paths[i]
                    })

    # Sort in descending order cuz we wanna show the worst classified first
    misclassified.sort(key=lambda x: x['confidence'], reverse=True)
    return misclassified



def rewrite_data_with_new_labels(dir_1, dir_2, misclassified_images):
    """
    Copy data from dir_1 to dir_2, changing the labels of misclassified images.

    dir_1: Current directory of the data.
    dir_2: Target directory where data will be rewritten.
    misclassified_images: List of misclassified images and their new labels. Gotten from the function above.
    """

    #Delete dir_2
    print("Deleting dir_2 Directory")
    if os.path.exists(dir_2):
        shutil.rmtree(dir_2)
    print("Writing dir_2 data Directory")


    # Create dir_2 if it doesn't exist
    if not os.path.exists(dir_2):
        os.makedirs(dir_2)

    # Create a set of misclassified image paths for quick lookup
    misclassified_paths = set([item['path'] for item in misclassified_images])

    # Mapping of predicted labels for misclassified images
    predicted_labels = {item['path']: class_names[item['predicted_label'].item()] for item in misclassified_images}


    # Iterate over dir_1 and copy files to dir_2
    for root, dirs, files in os.walk(dir_1):
        for file in tqdm(files, desc="Copying data"):
            src_path = os.path.join(root, file)

            # Determine the target directory based on whether the image is misclassified
            if src_path in misclassified_paths:
                # Use the new predicted label directory for misclassified images
                new_label_dir = os.path.join(dir_2, predicted_labels[src_path])
            else:
                # Use the same directory structure as dir_1 for correctly classified images
                rel_path = os.path.relpath(root, dir_1)
                new_label_dir = os.path.join(dir_2, rel_path)

            # Create target directory if it doesn't exist
            os.makedirs(new_label_dir, exist_ok=True)

            # Copy file to the new directory
            shutil.copy(src_path, os.path.join(new_label_dir, file))

# %% [markdown]
# # Below, we perform the automatic data cleaning process

# %%
#Parameters we actually care about and should change:
dirty_proportion = 0  # Define the starting dirty proportion of the dataset we will be using
confidence_threshold = 0.5 #If we are confident that the image is the other label, change the label
num_iterations = 10


#Define the clean, first dirty, and second dirty directories.
clean_dir = "Cropped_Data_4000_Three"
dirty_dir_1 = "Dirty Data 1"
dirty_dir_2 =  "Dirty Data 2"

#Define the CSVs for each one
clean_csv = "Clean_Labels.csv"
dirty_csv = "Dirty_Labels.csv"


# Initialize our datasets and csvs before going into the loop
create_labels_csv(clean_dir, clean_csv)
create_dirty_data(clean_dir, dirty_dir_1, dirty_proportion)
create_labels_csv(dirty_dir_1, dirty_csv)

# Double check our dirty accuracy - should be close to: 1 - 2/3*dirty_proportion
print(f"Our dirty proportion should be approximately: {1-2/3*dirty_proportion}")
label_accuracy = calculate_label_accuracy(clean_csv, dirty_csv)
print(f"Label accuracy of the dirty dataset: {label_accuracy}")


#Initialize what our current dirty dataset is for the iterative loop, and other starting variables
current_dirty_dataset = 1
label_accuracy_history = []
validation_accuracies = []

#Training params
arch = "deit" #(Model architecture we'll use) - best one is deit
validation_split = 0.2
batch_size = 64
num_workers = 2

dropout = 0
num_classes = 3

learning_rate = 0.0001
num_epochs = 1
L2 = 10**(-6)
momentum1 = 0.8
momentum2 = 0.9
stepsize = 3
gamma = 0.1

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device is {device}")
# Out:
# CSV file created at Clean_Labels.csv
# Deleting Dirty Data Directory
# Writing Dirty Data Directory
# Writing Data: 100%|██████████| 3860/3860 [00:00<00:00, 5898.89it/s]
# CSV file created at Dirty_Labels.csv
# Our dirty proportion should be approximately: 1.0
# Label accuracy of the dirty dataset: 1.0
# Device is cuda

# %% [markdown]
# ## We perform the data cleaning process below.
# ### It occurs in the following process:
#
# 1. Train a model on the current dirty dataset
#
# 2. Evaluate that model on the current dirty dataset. If the model is over the confidence threshold on an image, change the label and write the new dataset to the other dirty dataset. Log the new dataset's label accuracy. The other dirty dataset is the new current dataset.
#
# 3. Repreat steps 1-2 for the desired number of iterations.

# %%
for it in range(20):
    #Step 1: Train a model on the current dirty dataset
    if current_dirty_dataset == 1:
        dir_path = dirty_dir_1
        new_dir_path = dirty_dir_2
    elif current_dirty_dataset == 2:
        dir_path = dirty_dir_2
        new_dir_path = dirty_dir_1
    else:
        raise

    print(f"Our Current Dataset is {dir_path}")
    #Track the progress of the label accuracy
    create_labels_csv(dir_path, dirty_csv)
    label_accuracy = calculate_label_accuracy(clean_csv, dirty_csv)
    print(f"New label accuracy is {label_accuracy}")
    label_accuracy_history.append(label_accuracy)

    #Make our dataset w/ the dirty data
    train_loader, val_loader = prepare_and_get_loaders(validation_split, batch_size, num_workers, dir_path)

    #Make our model with the best one we found
    model = load_model(arch, dropout, num_classes)

    #Train the model
    model, hist, final_val_accuracy = finetune(model,
                                          train_loader,
                                          val_loader,
                                          learning_rate,
                                          num_epochs,
                                          L2,
                                          momentum1,
                                          momentum2,
                                          stepsize,
                                          gamma)
    validation_accuracies.append(final_val_accuracy)


    #Step 2: Evaluate the model on the dataset and keep track of the ones above the confidence threshold.
    #Then, write the data to the new directory with the only change being that the images the model wants to relabel are
    #relabelled
    clean_loader, class_names = cleaning_loader(dir_path)
    misclassified_images = get_misclassified_images(clean_loader, model, class_names, confidence_threshold)
    print(f"We are going to relabel {len(misclassified_images)} images")

    #cuda cleaning
    if device == "cuda":
        del model
        torch.cuda.empty_cache() #cuda memory was filling up


    #write the data to new directories, and switch the current dirty dataset
    rewrite_data_with_new_labels(dir_path, new_dir_path, misclassified_images)
    if current_dirty_dataset == 1:
        current_dirty_dataset = 2
    elif current_dirty_dataset == 2:
        current_dirty_dataset = 1
    else:
      raise

    #Accuracy will be logged at new loop - loop until iterations are complete
# Out:
# Our Current Dataset is Dirty Data 1
# CSV file created at Dirty_Labels.csv
# New label accuracy is 1.0
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.76s/it]
# Epoch [1/1], Training Loss: 0.6528, Validation Loss: 0.4881, Validation Accuracy: 83.81%
# Evaluating: 100%|██████████| 3860/3860 [01:03<00:00, 60.57it/s]
# We are going to relabel 376 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 1153/1153 [00:00<00:00, 8197.17it/s]
# Copying data: 100%|██████████| 375/375 [00:00<00:00, 5499.95it/s]
# Copying data: 100%|██████████| 2332/2332 [00:00<00:00, 5441.80it/s]
# Our Current Dataset is Dirty Data 2
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.9025906735751296
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.31s/it]
# Epoch [1/1], Training Loss: 0.5197, Validation Loss: 0.3940, Validation Accuracy: 85.62%
# Evaluating: 100%|██████████| 3860/3860 [01:03<00:00, 60.66it/s]
# We are going to relabel 303 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 1210/1210 [00:00<00:00, 7903.34it/s]
# Copying data: 100%|██████████| 360/360 [00:00<00:00, 7639.78it/s]
# Copying data: 100%|██████████| 2290/2290 [00:00<00:00, 8084.17it/s]
# Our Current Dataset is Dirty Data 1
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.8585492227979274
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.17s/it]
# Epoch [1/1], Training Loss: 0.4957, Validation Loss: 0.3156, Validation Accuracy: 86.79%
# Evaluating: 100%|██████████| 3860/3860 [01:03<00:00, 60.93it/s]
# We are going to relabel 298 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 1007/1007 [00:00<00:00, 5663.15it/s]
# Copying data: 100%|██████████| 357/357 [00:00<00:00, 5776.70it/s]
# Copying data: 100%|██████████| 2496/2496 [00:00<00:00, 5464.14it/s]
# Our Current Dataset is Dirty Data 2
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.8357512953367876
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.08s/it]
# Epoch [1/1], Training Loss: 0.4490, Validation Loss: 0.2538, Validation Accuracy: 89.38%
# Evaluating: 100%|██████████| 3860/3860 [01:03<00:00, 60.46it/s]
# We are going to relabel 219 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 1199/1199 [00:00<00:00, 7423.27it/s]
# Copying data: 100%|██████████| 247/247 [00:00<00:00, 8250.85it/s]
# Copying data: 100%|██████████| 2414/2414 [00:00<00:00, 8285.28it/s]
# Our Current Dataset is Dirty Data 1
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.8202072538860103
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:54<00:00, 114.14s/it]
# Epoch [1/1], Training Loss: 0.4343, Validation Loss: 0.2138, Validation Accuracy: 90.16%
# Evaluating: 100%|██████████| 3860/3860 [01:03<00:00, 60.41it/s]
# We are going to relabel 207 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 1320/1320 [00:00<00:00, 8274.67it/s]
# Copying data: 100%|██████████| 263/263 [00:00<00:00, 7774.02it/s]
# Copying data: 100%|██████████| 2277/2277 [00:00<00:00, 8064.61it/s]
# Our Current Dataset is Dirty Data 2
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.800259067357513
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.33s/it]
# Epoch [1/1], Training Loss: 0.5153, Validation Loss: 0.5177, Validation Accuracy: 78.76%
# Evaluating: 100%|██████████| 3860/3860 [01:03<00:00, 60.92it/s]
# We are going to relabel 667 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 1466/1466 [00:00<00:00, 7930.68it/s]
# Copying data: 100%|██████████| 269/269 [00:00<00:00, 8816.25it/s]
# Copying data: 100%|██████████| 2125/2125 [00:00<00:00, 6098.14it/s]
# Our Current Dataset is Dirty Data 1
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.6816062176165804
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.86s/it]
# Epoch [1/1], Training Loss: 0.4561, Validation Loss: 0.2303, Validation Accuracy: 90.03%
# Evaluating: 100%|██████████| 3860/3860 [01:03<00:00, 60.77it/s]
# We are going to relabel 204 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 2114/2114 [00:00<00:00, 8215.48it/s]
# Copying data: 100%|██████████| 90/90 [00:00<00:00, 7120.52it/s]
# Copying data: 100%|██████████| 1656/1656 [00:00<00:00, 7741.72it/s]
# Our Current Dataset is Dirty Data 2
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.6792746113989637
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.89s/it]
# Epoch [1/1], Training Loss: 0.4112, Validation Loss: 0.2124, Validation Accuracy: 92.75%
# Evaluating: 100%|██████████| 3860/3860 [01:03<00:00, 60.63it/s]
# We are going to relabel 140 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 2110/2110 [00:00<00:00, 8295.07it/s]
# Copying data: 100%|██████████| 87/87 [00:00<00:00, 7431.11it/s]
# Copying data: 100%|██████████| 1663/1663 [00:00<00:00, 8308.96it/s]
# Our Current Dataset is Dirty Data 1
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.677720207253886
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.21s/it]
# Epoch [1/1], Training Loss: 0.3820, Validation Loss: 0.1876, Validation Accuracy: 91.19%
# Evaluating: 100%|██████████| 3860/3860 [01:03<00:00, 60.56it/s]
# We are going to relabel 189 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 2112/2112 [00:00<00:00, 8300.59it/s]
# Copying data: 100%|██████████| 70/70 [00:00<00:00, 5548.86it/s]
# Copying data: 100%|██████████| 1678/1678 [00:00<00:00, 8387.85it/s]
# Our Current Dataset is Dirty Data 2
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.6502590673575129
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:54<00:00, 114.08s/it]
# Epoch [1/1], Training Loss: 0.3700, Validation Loss: 0.2284, Validation Accuracy: 91.32%
# Evaluating: 100%|██████████| 3860/3860 [01:03<00:00, 60.51it/s]
# We are going to relabel 163 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 2252/2252 [00:00<00:00, 7679.19it/s]
# Copying data: 100%|██████████| 49/49 [00:00<00:00, 5757.05it/s]
# Copying data: 100%|██████████| 1559/1559 [00:00<00:00, 8361.60it/s]
# Our Current Dataset is Dirty Data 1
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.6310880829015544
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.37s/it]
# Epoch [1/1], Training Loss: 0.3409, Validation Loss: 0.1620, Validation Accuracy: 93.52%
# Evaluating: 100%|██████████| 3860/3860 [01:04<00:00, 60.21it/s]
# We are going to relabel 144 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 2341/2341 [00:00<00:00, 8368.71it/s]
# Copying data: 100%|██████████| 22/22 [00:00<00:00, 4647.43it/s]
# Copying data: 100%|██████████| 1497/1497 [00:00<00:00, 8390.51it/s]
# Our Current Dataset is Dirty Data 2
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.6253886010362695
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:54<00:00, 114.33s/it]
# Epoch [1/1], Training Loss: 0.3050, Validation Loss: 0.1661, Validation Accuracy: 91.97%
# Evaluating: 100%|██████████| 3860/3860 [01:03<00:00, 60.67it/s]
# We are going to relabel 178 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 2323/2323 [00:00<00:00, 8068.11it/s]
# Copying data: 100%|██████████| 3/3 [00:00<00:00, 2959.29it/s]
# Copying data: 100%|██████████| 1534/1534 [00:00<00:00, 7864.71it/s]
# Our Current Dataset is Dirty Data 1
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.6080310880829015
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.52s/it]
# Epoch [1/1], Training Loss: 0.3122, Validation Loss: 0.2585, Validation Accuracy: 90.67%
# Evaluating: 100%|██████████| 3860/3860 [01:03<00:00, 60.81it/s]
# We are going to relabel 262 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 2434/2434 [00:00<00:00, 5482.56it/s]
# Copying data: 100%|██████████| 1426/1426 [00:00<00:00, 5449.63it/s]
# Our Current Dataset is Dirty Data 2
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.649740932642487
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.19s/it]
# Epoch [1/1], Training Loss: 0.2934, Validation Loss: 0.1555, Validation Accuracy: 94.04%
# Evaluating: 100%|██████████| 3860/3860 [01:03<00:00, 61.05it/s]
# We are going to relabel 126 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 2202/2202 [00:00<00:00, 8286.83it/s]
# Copying data: 100%|██████████| 1658/1658 [00:00<00:00, 8641.35it/s]
# Our Current Dataset is Dirty Data 1
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.6621761658031088
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.97s/it]
# Epoch [1/1], Training Loss: 0.3334, Validation Loss: 0.1541, Validation Accuracy: 92.75%
# Evaluating: 100%|██████████| 3860/3860 [01:04<00:00, 59.98it/s]
# We are going to relabel 158 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 2126/2126 [00:00<00:00, 8268.96it/s]
# Copying data: 100%|██████████| 1734/1734 [00:00<00:00, 8292.81it/s]
# Our Current Dataset is Dirty Data 2
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.666580310880829
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.30s/it]
# Epoch [1/1], Training Loss: 0.3179, Validation Loss: 0.2175, Validation Accuracy: 90.93%
# Evaluating: 100%|██████████| 3860/3860 [01:03<00:00, 60.76it/s]
# We are going to relabel 161 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 2040/2040 [00:00<00:00, 4774.47it/s]
# Copying data: 100%|██████████| 1820/1820 [00:00<00:00, 5054.73it/s]
# Our Current Dataset is Dirty Data 1
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.6479274611398964
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.48s/it]
# Epoch [1/1], Training Loss: 0.2943, Validation Loss: 0.2470, Validation Accuracy: 89.90%
# Evaluating: 100%|██████████| 3860/3860 [01:04<00:00, 59.50it/s]
# We are going to relabel 288 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 2155/2155 [00:00<00:00, 7676.75it/s]
# Copying data: 100%|██████████| 1705/1705 [00:00<00:00, 7786.61it/s]
# Our Current Dataset is Dirty Data 2
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.6699481865284974
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.69s/it]
# Epoch [1/1], Training Loss: 0.3386, Validation Loss: 0.2377, Validation Accuracy: 92.36%
# Evaluating: 100%|██████████| 3860/3860 [01:05<00:00, 59.04it/s]
# We are going to relabel 227 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 1921/1921 [00:00<00:00, 6513.62it/s]
# Copying data: 100%|██████████| 1939/1939 [00:00<00:00, 8389.79it/s]
# Our Current Dataset is Dirty Data 1
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.6922279792746114
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.06s/it]
# Epoch [1/1], Training Loss: 0.3277, Validation Loss: 0.3572, Validation Accuracy: 83.03%
# Evaluating: 100%|██████████| 3860/3860 [01:04<00:00, 60.29it/s]
# We are going to relabel 558 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 1730/1730 [00:00<00:00, 7801.64it/s]
# Copying data: 100%|██████████| 2130/2130 [00:00<00:00, 8150.80it/s]
# Our Current Dataset is Dirty Data 2
# CSV file created at Dirty_Labels.csv
# New label accuracy is 0.6290155440414508
# My Device is cuda
# Training Epoch: 100%|██████████| 1/1 [01:53<00:00, 113.33s/it]
# Epoch [1/1], Training Loss: 0.2989, Validation Loss: 0.1830, Validation Accuracy: 91.19%
# Evaluating: 100%|██████████| 3860/3860 [01:04<00:00, 60.24it/s]
# We are going to relabel 209 images
# Deleting dir_2 Directory
# Writing dir_2 data Directory
# Copying data: 0it [00:00, ?it/s]
# Copying data: 100%|██████████| 2284/2284 [00:00<00:00, 8127.43it/s]
# Copying data: 100%|██████████| 1576/1576 [00:00<00:00, 7800.53it/s]

# %%
title = "Accuracies vs. Iteration for 50% Confidence Threshold, 0% Dirty Data"

plot_label_history([x * 100 for x in label_accuracy_history], validation_accuracies, title)

# %% [markdown]
# # junk below

# %%
clean_dir = r"C:\Users\Brandon\Desktop\Classes\E208\Homework\E208_Final\Automatic Data Cleaning\Cropped_Data_400"
create_labels_csv(clean_dir, 'Clean_Labels.csv')

dirty_dir = r"C:\Users\Brandon\Desktop\Classes\E208\Homework\E208_Final\Automatic Data Cleaning\Dirty Data"
x = 0.5
create_dirty_data(clean_dir, dirty_dir, x)
create_labels_csv(dirty_dir, "Dirty_Labels.csv")


label_accuracy = calculate_label_accuracy("Clean_Labels.csv", "Dirty_Labels.csv")
print(f"Label accuracy of the dirty dataset: {label_accuracy}")
# Out:
# CSV file created at Clean_Labels.csv
# Deleting Dirty Data Directory
# Writing Dirty Data Directory
# Writing Data: 100%|█████████████████████████████████████████████████████████████████| 385/385 [00:00<00:00, 876.39it/s]
# CSV file created at Dirty_Labels.csv
# Label accuracy of the dirty dataset: 0.6675324675324675

# %% [markdown]
# # Train a Model on the Dirty Data

# %%
#Dataset parameters
validation_split = 0.1
batch_size = 64
num_workers = 0
dir_path = "Dirty Data 1"

train_loader, val_loader = prepare_and_get_loaders(validation_split, batch_size, num_workers, dir_path)

# %%
#Model Parameters
results = {}

for arch in ["resnet18"]:
    dropout = 0
    num_classes = 3
    model = load_model(arch, dropout, num_classes)

    #Finetuning Parameters
    learning_rate = 0.0001
    num_epochs = 5
    L2 = 10**(-6)
    momentum1 = 0.8
    momentum2 = 0.9
    stepsize = 3
    gamma = 0.1
    model, hist, final_val_accuracy = finetune(model,
                                              train_loader,
                                              val_loader,
                                              learning_rate,
                                              num_epochs,
                                              L2,
                                              momentum1,
                                              momentum2,
                                              stepsize,
                                              gamma)
    results[arch] = final_val_accuracy
    print(f"Our final validation accuracy accuracy using the full CNN is {final_val_accuracy:.2f}%")
# Out:
# My Device is cpu
# Training Epoch:  20%|█████████████▌                                                      | 1/5 [00:29<01:57, 29.40s/it]
# Epoch [1/5], Training Loss: 1.1369, Validation Loss: 1.1894, Validation Accuracy: 31.58%
# Training Epoch:  40%|███████████████████████████▏                                        | 2/5 [00:56<01:24, 28.01s/it]
# Epoch [2/5], Training Loss: 0.6815, Validation Loss: 1.2769, Validation Accuracy: 31.58%
# Training Epoch:  60%|████████████████████████████████████████▊                           | 3/5 [01:22<00:54, 27.08s/it]
# Epoch [3/5], Training Loss: 0.4524, Validation Loss: 1.3125, Validation Accuracy: 26.32%
# Training Epoch:  80%|██████████████████████████████████████████████████████▍             | 4/5 [01:48<00:26, 26.71s/it]
# Epoch [4/5], Training Loss: 0.3020, Validation Loss: 1.3084, Validation Accuracy: 26.32%
# Training Epoch: 100%|████████████████████████████████████████████████████████████████████| 5/5 [02:14<00:00, 26.99s/it]
# Epoch [5/5], Training Loss: 0.3268, Validation Loss: 1.3160, Validation Accuracy: 23.68%
# Our final validation accuracy accuracy using the full CNN is 23.68%
